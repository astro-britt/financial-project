# %%
# preamble: packages we need
from pandas import DataFrame, Series
import pandas as pd
import pandas.io.data as web
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import cPickle as pickle
import csv
from sklearn import cluster
from sklearn import metrics
import pylab as pl
from tsne import *
from mpl_toolkits.mplot3d import Axes3D


#%matplotlib inline

# so as not to kill the internet connection, I've saved the data from yahoo to disk
load_from_disk = True
filename = 'yahoo_data.p'
if 'price_data' in locals():
    pass
elif load_from_disk:
    with open(filename, 'rb') as p:
        price_data = pickle.load(p)
    with open('constituents.csv', 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        all_sectors = dict()
        all_names = dict()
        for row in reader:
            all_sectors[row['Symbol']] = row['Sector']
            all_names[row['Symbol']] = row['Name']
else:
    # here is how you would get the data from the web
    # I got this file from here: http://data.okfn.org/data/core/s-and-p-500-companies
    with open('constituents.csv', 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            all_tickers.append(row['Symbol'])
            all_sectors[row['Symbol']] = row['Sector']
            
    # end date is implicitly today
    start_date = '2001-01-01'
    price_data = {}
    bad_tickers = []
    for ticker in all_tickers:
        try:
            price_data[ticker] = web.get_data_yahoo(ticker, start_date)
        except IOError as ioe:
            bad_tickers.append(ticker)
    print len(bad_tickers), "bad tickers =", bad_tickers
    pickle.dump(price_data, open(filename, 'wb'))
    

price = DataFrame({tic: data['Adj Close'] for tic, data in price_data.iteritems()})
print price.columns
print len(price.keys())
temp_raw_returns = price.pct_change().apply(np.log1p)[:1000].dropna(axis=1,thresh=999).fillna(0.0)
raw_returns = temp_raw_returns
#raw_returns = [temp_raw_returns[i] for i in range(len(temp_raw_returns)) if len(np.where(temp_raw_returns[i] == 0.)) == 0]
print len(raw_returns.keys())
n_days = max(raw_returns.count())
returns = raw_returns.copy()
missing_tickers = []
for k in returns:
    if returns[k].count() != n_days:
        missing_tickers.append(k)
        del returns[k]
        
print type(returns)
df = returns.as_matrix().transpose()
#plt.plot(df[3,:])
#plt.show()
# Out:
# Index([u'A', u'AA', u'AAPL', u'ABBV', u'ABC', u'ABT', u'ACE', u'ACN', u'ACT',
#        u'ADBE',
#        ...
#        u'XLNX', u'XOM', u'XRAY', u'XRX', u'XYL', u'YHOO', u'YUM', u'ZION',
#        u'ZMH', u'ZTS'],
#       dtype='object', length=491)
# 491
# 417
# <class 'pandas.core.frame.DataFrame'>

# %%
print df.shape
print df
print df.mean(axis=1).shape
normed = ((df.T-df.mean(axis=1) )/ df.std(axis=1)).T#((df-df.mean(axis=0) )/ df.std(axis=0))#
print normed
# Out:
# (417, 1000)
# [[ 0.          0.09820986  0.03716282 ...,  0.00752794 -0.00125078
#   -0.00711729]
#  [ 0.          0.01347469  0.03198767 ...,  0.00127874  0.0028713
#    0.00190965]
#  [ 0.          0.09607172  0.04112904 ...,  0.00094031  0.00406987
#   -0.01336721]
#  ...,
#  [ 0.          0.09309042 -0.04546237 ...,  0.01703898 -0.00107328
#    0.01306865]
#  [ 0.          0.05519888  0.00184955 ..., -0.00798881  0.00303029
#    0.00086414]
#  [ 0.          0.03282347 -0.02038806 ...,  0.00248711  0.01176566
#   -0.01762736]]
# (417,)
# [[  2.19942916e-02   2.86534862e+00   1.09792550e+00 ...,   2.39941792e-01
#    -1.42180913e-02  -1.84064202e-01]
#  [ -2.40890369e-03   5.80814498e-01   1.38211018e+00 ...,   5.29385143e-02
#     1.21869178e-01   8.02464511e-02]
#  [ -4.77997332e-02   3.12802033e+00   1.31179333e+00 ...,  -1.67161237e-02
#     8.67370120e-02  -4.89676309e-01]
#  ...,
#  [ -2.30461890e-02   2.15502803e+00  -1.08674771e+00 ...,   3.75621673e-01
# ...

# %%
print 'running...'
k = 9
km = cluster.KMeans(n_clusters=k)
km.fit(normed)

labels = km.labels_
print 'done'
# Out:
# running...
# done

# %%
d = dict()
sector_names = ['Industrials', 'Health Care', 'Information Technology', 'Financials', 'Utilities', 'Materials', 'Consumer Staples', 'Consumer Discretionary','Energy','Telecommunication Services']
for sector in sector_names:
    d[sector] = np.zeros([k])
real_labels = []
i=0
for ticker in raw_returns.keys():
    sector = all_sectors[ticker]
    real_labels.append(sector_names.index(sector))
    d[sector][int(labels[i])] = d[sector][int(labels[i])]+1
    i+=1
for key, value in d.items():
    print '%35s'%key,'\t',
    print value
# Out:
#                         Industrials 	[  5.   0.   0.  26.   0.   0.   0.  11.  15.]
#          Telecommunication Services 	[ 1.  0.  0.  0.  0.  0.  0.  3.  0.]
#              Consumer Discretionary 	[  0.   1.   0.  13.   0.   0.   0.   9.  39.]
#                           Utilities 	[  0.   0.   0.   0.  27.   0.   0.   1.   0.]
#                    Consumer Staples 	[ 27.   0.   0.   0.   0.   0.   0.   0.   5.]
#                         Health Care 	[ 35.   1.   0.   0.   0.   1.   0.   9.   1.]
#                           Materials 	[  2.   0.   0.  22.   0.   0.   0.   1.   2.]
#              Information Technology 	[  0.  42.   0.   0.   0.   0.   0.   7.   2.]
#                              Energy 	[  0.   0.  33.   0.   1.   0.   0.   2.   0.]
#                          Financials 	[  0.   0.   0.   1.   0.  19.  17.  34.   2.]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=400)
X_r = pca.fit_transform(normed)
plt.figure()
plt.scatter(X_r[:,0],X_r[:,1],c=labels)
plt.figure()
plt.scatter(X_r[:,0],X_r[:,2],c=labels)
plt.figure()
plt.scatter(X_r[:,1],X_r[:,2],c=labels)

print normed.shape
print X_r.shape
abs_normed = np.abs(X_r).mean(axis=0)
#eiv = np.linalg.eigvals(np.cov(normed.transpose()))
plt.figure()
plt.plot(abs_normed)
plt.show()
# Out:
# (417, 1000)
# (417, 400)

# %%
plt.figure()
plt.scatter(X_r[:,0],X_r[:,1],c=real_labels)
plt.figure()
plt.scatter(X_r[:,0],X_r[:,2],c=real_labels)
plt.figure()
plt.scatter(X_r[:,1],X_r[:,2],c=real_labels)
plt.show()

# %%
#from tsne import *
print 'Calculating tsne...'
Y = tsne(X=X_r,initial_dims=20,perplexity=100,no_dims=3)
# Out:
# Calculating tsne...
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point  0  of  417 ...
# Mean value of sigma:  9.5234644068
# Iteration  10 : error is  10.7330569881
# Iteration  20 : error is  10.5057917788
# Iteration  30 : error is  10.9783969734
# Iteration  40 : error is  10.7303172478
# Iteration  50 : error is  10.604685494
# Iteration  60 : error is  10.5796109358
# Iteration  70 : error is  10.4993598711
# Iteration  80 : error is  10.5123547821
# Iteration  90 : error is  10.5286381321
# Iteration  100 : error is  10.5343088452
# Iteration  110 : error is  0.624141230961
# Iteration  120 : error is  0.355242126455
# Iteration  130 : error is  0.307207732298
# Iteration  140 : error is  0.284629594142
# Iteration  150 : error is  0.273669650615
# Iteration  160 : error is  0.265238707001
# Iteration  170 : error is  0.261266506064
# Iteration  180 : error is  0.258608002193
# Iteration  190 : error is  0.256088167028
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
Y = np.array(Y)
colors = ['r','g','y','b','grey','m','black','orange','pink']
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in range(9):
    index = np.where(np.array(real_labels)==i)[0]
    ax.plot(Y[index,0],Y[index,1], Y[index,2], 'o',color=colors[i], label=sector_names[i])
plt.legend(loc='upper left', numpoints=1, ncol=3, fontsize=10, bbox_to_anchor=(0,0))
plt.show()

# %%
calculate_best_k = False
if calculate_best_k:
    ns = np.arange(2,40)
    ss = []
    for n in ns:
        print 'k-means for k=%s'%str(n)
        repeat = 10
        sil = 0
        for i in range(repeat):
            km = cluster.KMeans(n_clusters=n)
            km.fit(Y)

            labels = km.labels_
            sil += metrics.silhouette_score(Y, labels)
        sil /= repeat
        ss.append(sil)

    plt.plot (ns, ss)
    pl.show()
    k = np.argmax(ss)
else:
    k = 22
print k
# Out:
# 22

# %%
print 'running...'
km = cluster.KMeans(n_clusters=k)
km.fit(Y)

k_labels = km.labels_
print 'done'
# Out:
# running...
# done

# %%
i=0
cluster_ans = np.empty([len(raw_returns.keys()), 4], dtype='|S40')
for ticker in raw_returns.keys():
    cluster_ans[i,:] = np.array([ticker, str(k_labels[i]), all_sectors[ticker], all_names[ticker]])
    i+=1

# %%
from mpl_toolkits.mplot3d import proj3d

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(Y[:,0],Y[:,1], Y[:,2], c=k_labels)
plt.show()

# %%
import math
#from tsne import *
print 'Calculating tsne...'
Y_2d = tsne(X=X_r,initial_dims=20,perplexity=100,no_dims=2)
for name, x, y, col in zip(cluster_ans[:400,3], Y_2d[:400,0],Y_2d[:400,1],k_labels):
    plt.annotate(name, xy=(x,y), xytext=(0,0), textcoords='offset points', ha='center', va = 'center', size='small', color=[math.cos(col/22.0*2*3.14)/2.0+0.5,math.sin(col/22.0*2*3.14)/2.0+0.5,col/22.0])
plt.axis([-10,10, -10, 10])
plt.show()
# Out:
# Calculating tsne...
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point  0  of  417 ...
# Mean value of sigma:  9.5234644068
# Iteration  10 : error is  10.8895566015
# Iteration  20 : error is  10.53181493
# Iteration  30 : error is  10.5529129941
# Iteration  40 : error is  10.5676072895
# Iteration  50 : error is  10.5851171115
# Iteration  60 : error is  10.6365979348
# Iteration  70 : error is  10.5726168903
# Iteration  80 : error is  10.6243348353
# Iteration  90 : error is  10.6489937364
# Iteration  100 : error is  10.5486909704
# Iteration  110 : error is  0.60193468813
# Iteration  120 : error is  0.398059102428
# Iteration  130 : error is  0.371533384266
# Iteration  140 : error is  0.345989209759
# Iteration  150 : error is  0.342290500291
# Iteration  160 : error is  0.339362956516
# Iteration  170 : error is  0.338529921568
# Iteration  180 : error is  0.337530732164
# Iteration  190 : error is  0.333135918111
# ...

# %%
cluster_ans_sorted = cluster_ans[np.argsort(cluster_ans[:,1])]
i = '0'
print '%10s\t%40s'%('Company name','Sector')
print '-'*100
for (asdf,qwerty,zxcv,hehe) in cluster_ans_sorted:
    if qwerty!=i:
        i=qwerty
        print '-'*100
    print '%30s\t%40s\t%10s'%(hehe,zxcv,qwerty)
# Out:
# Company name	                                  Sector
# ----------------------------------------------------------------------------------------------------
#                  Zions Bancorp	                              Financials	         0
#                       M&T Bank	                              Financials	         0
#                        KeyCorp	                              Financials	         0
#            JPMorgan Chase & Co	                              Financials	         0
#         PNC Financial Services	                              Financials	         0
#              Regions Financial	                              Financials	         0
#                 SunTrust Banks	                              Financials	         0
#        Bank of New York Mellon	                              Financials	         0
#              State Street Corp	                              Financials	         0
# ...

# %%
print normed
print cluster_ans
# Out:
# [[  2.19942916e-02   2.86534862e+00   1.09792550e+00 ...,   2.39941792e-01
#    -1.42180913e-02  -1.84064202e-01]
#  [ -2.40890369e-03   5.80814498e-01   1.38211018e+00 ...,   5.29385143e-02
#     1.21869178e-01   8.02464511e-02]
#  [ -4.77997332e-02   3.12802033e+00   1.31179333e+00 ...,  -1.67161237e-02
#     8.67370120e-02  -4.89676309e-01]
#  ...,
#  [ -2.30461890e-02   2.15502803e+00  -1.08674771e+00 ...,   3.75621673e-01
#    -4.81580652e-02   2.82726248e-01]
#  [ -5.48987674e-02   2.77770259e+00   4.00132298e-02 ...,  -4.64854586e-01
#     1.00604258e-01  -1.05542055e-02]
#  [ -1.31694313e-02   2.16490198e+00  -1.36606283e+00 ...,   1.51867963e-01
#     7.67566288e-01  -1.18287066e+00]]
# [['A' '7' 'Health Care' 'Agilent Technologies']
#  ['AA' '4' 'Materials' 'Alcoa']
#  ['AAPL' '16' 'Information Technology' 'Apple']
#  ...,
#  ['YHOO' '16' 'Information Technology' 'Yahoo']
#  ['YUM' '17' 'Consumer Discretionary' 'Yum Brands']
#  ['ZION' '0' 'Financials' 'Zions Bancorp']]

# %%
cluster_mean_prices = dict()
for i in range(k):
    cluster_mean_prices[str(i)] = [np.zeros(len(normed[0,:])), 0]

i = 0
for (ticker, ncluster, sector, names) in cluster_ans:
    aux = cluster_mean_prices[ncluster][0]
    c = cluster_mean_prices[ncluster][1]
    cluster_mean_prices[ncluster] = [aux+normed[i,:], c+1]
    i+=1

for i in range(k):
    i = str(i)
    aux = cluster_mean_prices[i][0]
    c = cluster_mean_prices[i][1]
    cluster_mean_prices[i] = [aux/c, c]

# %%
i = 0
for element in cluster_mean_prices.values():
    plt.plot(element[0].cumsum(), label=str(i))
    i+=1
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
centroids_matrix = np.array([vector for (vector,c) in cluster_mean_prices.values() ])
std_centroids = StandardScaler().fit_transform(centroids_matrix.T).T
#for i in range(k):
#    plt.plot(std_centroids[i,:])
plt.show()

cov_mat = np.cov(std_centroids)
plt.matshow(cov_mat)
plt.show()

# %%
eigval = np.linalg.eigvals(cov_mat)
plt.hist(eigval, 15, range=(0.0, 2.5), normed=True, alpha=0.5, color='r', label="clustering")
def marcenko_limits(q, sigma):
    """compute upper and lower marcenko limits"""
    ss = sigma * sigma
    delta = 2.0 * ss * np.sqrt(1.0 / q)
    c = ss * (1.0 + 1.0 / q)
    lmax = c + delta
    lmin = c - delta
    return lmin, lmax
def marcenko(xs, q, sigma):
    """vectorized marcenko-pasteur law"""
    lmin, lmax = marcenko_limits(q, sigma)
    fac = q / (2.0 * np.pi * sigma * sigma)
    # nan_to_num is necessary to handle the case lambda = 0, fails to handle this case correctly for q <= 1.0
    return fac * np.sqrt(np.maximum((lmax - xs) * (xs - lmin), 0.0)) * np.nan_to_num(np.reciprocal(xs))
raw_e = eigval
xs = np.linspace(0,2,100)
eff_q = 3.9
eff_sigma = 0.7
# total density is less than one because we exclude some eigenvalues from MP density
lmin, lmax = marcenko_limits(eff_q, eff_sigma)
scale_factor = float(len(raw_e[np.logical_and(np.less(raw_e, lmax), np.greater(raw_e, lmin))])) / len(raw_e)
plt.plot(xs, scale_factor * marcenko(xs, eff_q, eff_sigma), label=('Q=%.2g $\sigma$=%.2g' % (eff_q, eff_sigma)), linewidth=3.0)
plt.legend()
plt.show()
