# %%
# preamble: packages we need
from pandas import DataFrame, Series
import pandas as pd
import pandas.io.data as web
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import cPickle as pickle
import csv
from sklearn import cluster
import pylab as pl
from tsne import *


#%matplotlib inline

# so as not to kill the internet connection, I've saved the data from yahoo to disk
load_from_disk = True
filename = 'yahoo_data.p'
if 'price_data' in locals():
    pass
elif load_from_disk:
    with open(filename, 'rb') as p:
        price_data = pickle.load(p)
    with open('constituents.csv', 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        all_sectors = dict()
        for row in reader:
            all_sectors[row['Symbol']] = row['Sector']
else:
    # here is how you would get the data from the web
    # I got this file from here: http://data.okfn.org/data/core/s-and-p-500-companies
    with open('constituents.csv', 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            all_tickers.append(row['Symbol'])
            all_sectors[row['Symbol']] = row['Sector']
            
    # end date is implicitly today
    start_date = '2001-01-01'
    price_data = {}
    bad_tickers = []
    for ticker in all_tickers:
        try:
            price_data[ticker] = web.get_data_yahoo(ticker, start_date)
        except IOError as ioe:
            bad_tickers.append(ticker)
    print len(bad_tickers), "bad tickers =", bad_tickers
    pickle.dump(price_data, open(filename, 'wb'))
    

price = DataFrame({tic: data['Adj Close'] for tic, data in price_data.iteritems()})
print price.columns
print len(price.keys())
raw_returns = price.pct_change().apply(np.log1p).fillna(0.0)[:1000]
n_days = max(raw_returns.count())
returns = raw_returns.copy()
missing_tickers = []
for k in returns:
    if returns[k].count() != n_days:
        missing_tickers.append(k)
        del returns[k]
        
print type(returns)
df = returns.as_matrix().transpose()
#plt.plot(df[3,:])
#plt.show()
# Out:
# Index([u'A', u'AA', u'AAPL', u'ABBV', u'ABC', u'ABT', u'ACE', u'ACN', u'ACT',
#        u'ADBE',
#        ...
#        u'XLNX', u'XOM', u'XRAY', u'XRX', u'XYL', u'YHOO', u'YUM', u'ZION',
#        u'ZMH', u'ZTS'],
#       dtype='object', length=491)
# 491
# <class 'pandas.core.frame.DataFrame'>

# %%
print df.shape
normed = np.nan_to_num(((df.T-df.mean(axis=1) )/ df.std(axis=1)).T)
# Out:
# (491, 1000)

# %%
print 'running...'
k = 9
km = cluster.KMeans(n_clusters=k)
km.fit(normed)

labels = km.labels_
print 'done'
# Out:
# running...
# done

# %%
d = dict()
sector_names = ['Industrials', 'Health Care', 'Information Technology', 'Financials', 'Utilities', 'Materials', 'Consumer Staples', 'Consumer Discretionary','Energy','Telecommunication Services']
for sector in sector_names:
    d[sector] = np.zeros([k])
real_labels = []
i=0
for ticker in price.keys():
    sector = all_sectors[ticker]
    real_labels.append(sector_names.index(sector))
    d[sector][int(labels[i])] = d[sector][int(labels[i])]+1
    i+=1
for key, value in d.items():
    print '%35s'%key,'\t',
    print value
# Out:
#                         Industrials 	[  0.   0.  46.   1.   0.   0.  15.   0.   1.]
#          Telecommunication Services 	[ 0.  0.  1.  0.  0.  0.  4.  0.  0.]
#              Consumer Discretionary 	[  0.  20.  31.   2.   0.   0.  28.   0.   1.]
#                           Utilities 	[  0.   0.   0.   0.  27.   0.   2.   0.   0.]
#                    Consumer Staples 	[  1.   2.   0.   0.   0.   0.  35.   0.   0.]
#                         Health Care 	[  0.   0.   1.   3.   0.   0.  49.   0.   0.]
#                           Materials 	[  0.   0.  23.   0.   0.   0.   6.   0.   0.]
#              Information Technology 	[  0.   0.   3.  46.   0.   0.  16.   0.   0.]
#                              Energy 	[  0.   0.   0.   0.   1.  32.  10.   0.   0.]
#                          Financials 	[  0.   0.   5.   1.   0.   0.  14.  15.  49.]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=490)
X_r = pca.fit_transform(normed)
plt.figure()
plt.scatter(X_r[:,0],X_r[:,1],c=labels)
plt.figure()
plt.scatter(X_r[:,0],X_r[:,2],c=labels)
plt.figure()
plt.scatter(X_r[:,1],X_r[:,2],c=labels)

print normed.shape
print X_r.shape
abs_normed = np.abs(X_r).mean(axis=0)
#eiv = np.linalg.eigvals(np.cov(normed.transpose()))
plt.figure()
plt.plot(abs_normed)
plt.show()
# Out:
# (491, 1000)
# (491, 490)

# %%
plt.figure()
plt.scatter(X_r[:,0],X_r[:,1],c=real_labels)
plt.figure()
plt.scatter(X_r[:,0],X_r[:,2],c=real_labels)
plt.figure()
plt.scatter(X_r[:,1],X_r[:,2],c=real_labels)
plt.show()

# %%
#from tsne import *
print 'Calculating tsne...'
Y = tsne(X=X_r,initial_dims=5,perplexity=100,no_dims=3)
# Out:
# Calculating tsne...
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point  0  of  491 ...
# Mean value of sigma:  6.33499656496
# Iteration  10 : error is  10.4121229991
# Iteration  20 : error is  9.6360979512
# Iteration  30 : error is  9.77161717428
# Iteration  40 : error is  9.73501864464
# Iteration  50 : error is  9.74607716751
# Iteration  60 : error is  9.73021274439
# Iteration  70 : error is  9.73547354938
# Iteration  80 : error is  9.71721851029
# Iteration  90 : error is  9.73943449705
# Iteration  100 : error is  9.73532144473
# Iteration  110 : error is  0.345184994425
# Iteration  120 : error is  0.237906882086
# Iteration  130 : error is  0.228205437465
# Iteration  140 : error is  0.225721001605
# Iteration  150 : error is  0.224007568084
# Iteration  160 : error is  0.222164076068
# Iteration  170 : error is  0.220717342176
# Iteration  180 : error is  0.219147387306
# Iteration  190 : error is  0.217940165552
# Iteration  200 : error is  0.212174366732
# Iteration  210 : error is  0.208116119599
# Iteration  220 : error is  0.207556348199
# Iteration  230 : error is  0.207288063389
# Iteration  240 : error is  0.207193511631
# Iteration  250 : error is  0.207129031003
# Iteration  260 : error is  0.20708104627
# Iteration  270 : error is  0.207043180969
# Iteration  280 : error is  0.207015283137
# Iteration  290 : error is  0.206997652919
# Iteration  300 : error is  0.206986343947
# Iteration  310 : error is  0.206978849449
# Iteration  320 : error is  0.206973875905
# Iteration  330 : error is  0.206970966083
# Iteration  340 : error is  0.206969107254
# Iteration  350 : error is  0.206967669403
# Iteration  360 : error is  0.206966541103
# Iteration  370 : error is  0.206965630804
# Iteration  380 : error is  0.206964818722
# Iteration  390 : error is  0.206964266492
# Iteration  400 : error is  0.206963912737
# Iteration  410 : error is  0.206963635659
# Iteration  420 : error is  0.20696331966
# Iteration  430 : error is  0.206962784502
# Iteration  440 : error is  0.206961905709
# Iteration  450 : error is  0.20696124214
# Iteration  460 : error is  0.206960963414
# Iteration  470 : error is  0.206960789992
# Iteration  480 : error is  0.206960642396
# Iteration  490 : error is  0.20696050066
# Iteration  500 : error is  0.206960361233
# Iteration  510 : error is  0.20696022091
# Iteration  520 : error is  0.206960086206
# Iteration  530 : error is  0.206959973228
# Iteration  540 : error is  0.206959888034
# Iteration  550 : error is  0.20695982855
# Iteration  560 : error is  0.206959784943
# Iteration  570 : error is  0.206959749623
# Iteration  580 : error is  0.206959720389
# Iteration  590 : error is  0.206959698064
# Iteration  600 : error is  0.206959681521
# Iteration  610 : error is  0.206959667994
# Iteration  620 : error is  0.206959656284
# Iteration  630 : error is  0.206959646438
# Iteration  640 : error is  0.206959637516
# Iteration  650 : error is  0.206959628541
# Iteration  660 : error is  0.206959619568
# Iteration  670 : error is  0.206959611078
# Iteration  680 : error is  0.206959603223
# Iteration  690 : error is  0.206959596195
# Iteration  700 : error is  0.206959590446
# Iteration  710 : error is  0.206959585917
# Iteration  720 : error is  0.206959582497
# Iteration  730 : error is  0.206959580005
# Iteration  740 : error is  0.206959577933
# Iteration  750 : error is  0.206959575949
# Iteration  760 : error is  0.206959573685
# Iteration  770 : error is  0.206959570823
# Iteration  780 : error is  0.206959566577
# Iteration  790 : error is  0.206959559634
# Iteration  800 : error is  0.206959548221
# Iteration  810 : error is  0.206959529945
# Iteration  820 : error is  0.206959499954
# Iteration  830 : error is  0.206959456805
# Iteration  840 : error is  0.206959412898
# Iteration  850 : error is  0.206959374192
# Iteration  860 : error is  0.206959344189
# Iteration  870 : error is  0.206959322493
# Iteration  880 : error is  0.206959306365
# Iteration  890 : error is  0.206959293686
# Iteration  900 : error is  0.206959283713
# Iteration  910 : error is  0.206959275918
# Iteration  920 : error is  0.206959270061
# Iteration  930 : error is  0.206959265699
# Iteration  940 : error is  0.206959262609
# Iteration  950 : error is  0.206959260399
# Iteration  960 : error is  0.206959258835
# Iteration  970 : error is  0.206959257755
# Iteration  980 : error is  0.20695925696
# Iteration  990 : error is  0.206959256383
# Iteration  1000 : error is  0.206959255926

# %%
plt.scatter(Y[:,0],Y[:,1],30,real_labels,alpha=.5)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(Y[:,0],Y[:,1], Y[:,2], c=real_labels, depthshade=True,s =40)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.legend(['i'*9])
plt.show()

# %%
Y = np.array(Y)
colors = ['r','g','y','b','grey','m','black','orange','pink']
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in range(9):
    index = np.where(np.array(real_labels)==i)[0]
    ax.plot(Y[index,0],Y[index,1], Y[index,2], 'o',color=colors[i], label=sector_names[i])
plt.legend(loc='upper left', numpoints=1, ncol=3, fontsize=10, bbox_to_anchor=(0,0))
plt.show()

# %%
print raw_returns[-1000:]
# Out:
#                    A        AA      AAPL  ABBV       ABC       ABT       ACE  \
# Date
# 2001-01-02  0.000000  0.000000  0.000000     0  0.000000  0.000000  0.000000
# 2001-01-03  0.098210  0.013475  0.096072     0  0.019827 -0.022325 -0.046520
# 2001-01-04  0.037163  0.031988  0.041129     0 -0.085786 -0.096108 -0.055479
